# %% [markdown]
# # Importing libraries

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import math
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %% [markdown]
# # Import Dataset

# %%
filename='LR_dataset.csv'
ds=pd.read_csv(filename)

# %%
X=ds['Close']
Y=ds['SMA']

# %% [markdown]
# # Train_Test_Split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.4)

# %% [markdown]
# # Linear Regression

# %%
model=LinearRegression()
model.fit(X_train.values.reshape(-1,1),Y_train.values.reshape(-1,1))
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
y_pred=model.predict(X_test.values.reshape(-1,1))

# %% [markdown]
# # Plot the graph

# %%
plt.scatter(X_test,Y_test,color='black')
plt.plot(X_test,y_pred,color='blue')
plt.xticks(())
plt.yticks(())

plt.show()

# %% [markdown]
# # Plot Scatter

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.scatter(ds['Close'],ds['SMA'])

# %%
import seaborn as sns
sns.set()

# %%
x=sns.pairplot(ds, hue='SMA', size=2.5)

# %% [markdown]
# # Performance Evaluation

# %%
from scipy.stats import pearsonr
r,p = pearsonr(X_test,Y_test)
print (r)
# Out:
# 0.958926524090829

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

rms = (mean_squared_error(Y_test, y_pred))
print(rms)
# Out:
# 3907.005788260755

# %%
print("R2_Score: %.2f" %r2_score(Y_test,y_pred))
# Out:
# R2_Score: 0.91

# %%
c = model.intercept_[0]

# %%
m = model.coef_[0,0]

# %%
print('Intercept is')
print(c)
print('Slope is')
print(m)
# Out:
# Intercept is
# 1250.3924136342648
# Slope is
# 0.8804390098042112

# %%
ds.corr(method='spearman')
# Out:
#           Close       SMA
# Close  1.000000  0.960761
# SMA    0.960761  1.000000

# %%
filename='LR_dataset.csv'
ds=pd.read_csv(filename)

# %%
xs=ds['Close']
ys=ds['SMA']
